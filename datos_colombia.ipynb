# %% [markdown]
# <a href="https://colab.research.google.com/github/Michell888/datos_colombia/blob/main/datos_colombia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datos = pd.read_excel("/content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos/datos_2006_2018.xlsx")
print(datos.shape)
datos.head()
# Out:
# (210847, 18)
#    Código Dane departamento        Departamento  Código Dane municipio  \
# 0                        15              BOYACA                  15114
# 1                        25        CUNDINAMARCA                  25754
# 2                        25        CUNDINAMARCA                  25214
# 3                        54  NORTE DE SANTANDER                  54405
# 4                        54  NORTE DE SANTANDER                  54518
#
#     Municipio Grupo cultivo Subgrupo Cultivo Desagregación cultivo   Año  \
# 0    BUSBANZA    HORTALIZAS   ACELGA  ACELGA                ACELGA  2006
# 1      SOACHA    HORTALIZAS   ACELGA  ACELGA                ACELGA  2006
# 2        COTA    HORTALIZAS   ACELGA  ACELGA                ACELGA  2006
# 3  LOS PATIOS    HORTALIZAS   ACELGA  ACELGA                ACELGA  2006
# 4    PAMPLONA    HORTALIZAS   ACELGA  ACELGA                ACELGA  2006
#
#   Periodo  Área sembrada (ha)  Área cosechada (ha)  Producción (t)  \
# ...

# %%
import pandas as pd
datos_2019 = pd.read_excel("/content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos/datos_2019_2024.xlsx")
print(datos_2019.shape)
datos_2019.head()
# Out:
# (141073, 17)
#    Código Dane departamento Departamento  Código Dane municipio Municipio  \
# 0                         5    Antioquia                   5001  Medellín
# 1                         5    Antioquia                   5001  Medellín
# 2                         5    Antioquia                   5001  Medellín
# 3                         5    Antioquia                   5001  Medellín
# 4                         5    Antioquia                   5001  Medellín
#
#        Desagregación cultivo   Cultivo Ciclo del cultivo Grupo cultivo  \
# 0  Aguacate demás variedades  Aguacate        Permanente      Frutales
# 1  Aguacate demás variedades  Aguacate        Permanente      Frutales
# 2  Aguacate demás variedades  Aguacate        Permanente      Frutales
# 3  Aguacate demás variedades  Aguacate        Permanente      Frutales
# 4  Aguacate demás variedades  Aguacate        Permanente      Frutales
#
#          Subgrupo   Año Periodo  Área sembrada (ha)  Área cosechada (ha)  \
# ...

# %%
import os

ruta_carpeta = "/content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos"  # Define the variable with the correct path
archivos_en_carpeta = os.listdir(ruta_carpeta)
print(ruta_carpeta) # Print the defined path
for archivo in archivos_en_carpeta:
    print(archivo)
# Out:
# /content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos
# datos_2019_2024.xlsx
# datos_2006_2018.xlsx

# %%
import pandas as pd
import os

ruta_carpeta = "/content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos"

# %%
# Standardize column names (lowercase and remove leading/trailing spaces)
datos.columns = datos.columns.str.lower().str.strip()
datos_2019.columns = datos_2019.columns.str.lower().str.strip()

# Get column names from both dataframes
cols_2006_2018 = datos.columns.tolist()
cols_2019_2024 = datos_2019.columns.tolist()

# Find missing columns in each dataframe
missing_in_2019_2024 = list(set(cols_2006_2018) - set(cols_2019_2024))
missing_in_2006_2018 = list(set(cols_2019_2024) - set(cols_2006_2018))

# Add missing columns with NaN values to each dataframe
for col in missing_in_2019_2024:
    datos_2019[col] = None

for col in missing_in_2006_2018:
    datos[col] = None

# Ensure columns are in the same order before concatenating
datos_2019_2024 = datos_2019[cols_2006_2018]

print("Columns after alignment:")
print("Datos 2006-2018:", datos.columns.tolist())
print("Datos 2019-2024:", datos_2019_2024.columns.tolist())
# Out:
# Columns after alignment:
# Datos 2006-2018: ['código dane departamento', 'departamento', 'código dane municipio', 'municipio', 'grupo cultivo', 'subgrupo', 'cultivo', 'desagregación cultivo', 'año', 'periodo', 'área sembrada (ha)', 'área cosechada (ha)', 'producción (t)', 'rendimiento (t/ha)', 'estado físico del cultivo', 'nombre científico del cultivo', 'ciclo del cultivo', 'unnamed: 17']
# Datos 2019-2024: ['código dane departamento', 'departamento', 'código dane municipio', 'municipio', 'grupo cultivo', 'subgrupo', 'cultivo', 'desagregación cultivo', 'año', 'periodo', 'área sembrada (ha)', 'área cosechada (ha)', 'producción (t)', 'rendimiento (t/ha)', 'estado físico del cultivo', 'nombre científico del cultivo', 'ciclo del cultivo', 'unnamed: 17']

# %%
import pandas as pd
import os
import unicodedata

def remove_accents(text):
    if isinstance(text, str):
        return ''.join(c for c in unicodedata.normalize('NFD', text) if unicodedata.category(c) != 'Mn')
    return text

ruta_carpeta = "/content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos" # Corrected path to include 'datos' subfolder
output_path = os.path.join("/content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA", "datos_2006_2024.xlsx") # Output path remains in the parent folder

# Load dataframes
datos_2006_2018 = pd.read_excel(os.path.join(ruta_carpeta, "datos_2006_2018.xlsx"))
datos_2019_2024 = pd.read_excel(os.path.join(ruta_carpeta, "datos_2019_2024.xlsx"))

# Standardize column names (lowercase and remove leading/trailing spaces)
datos_2006_2018.columns = datos_2006_2018.columns.str.lower().str.strip()
datos_2019_2024.columns = datos_2019_2024.columns.str.lower().str.strip()

# Get column names from both dataframes
cols_2006_2018 = datos_2006_2018.columns.tolist()
cols_2019_2024 = datos_2019_2024.columns.tolist()

# Find missing columns in each dataframe and add them
missing_in_2019_2024 = list(set(cols_2006_2018) - set(cols_2019_2024))
missing_in_2006_2018 = list(set(cols_2019_2024) - set(cols_2006_2018))

for col in missing_in_2019_2024:
    datos_2019_2024[col] = None

for col in missing_in_2006_2018:
    datos_2006_2018[col] = None

# Ensure columns are in the same order before concatenating
datos_2019_2024 = datos_2019_2024[cols_2006_2018]

# Concatenate dataframes
datos_combinados = pd.concat([datos_2006_2018, datos_2019_2024], ignore_index=True)

# Convert all string columns to lowercase and remove accents
for col in datos_combinados.columns:
    if datos_combinados[col].dtype == 'object':
        try:
            datos_combinados[col] = datos_combinados[col].str.lower().apply(remove_accents)
        except AttributeError:
            # Handle cases where a column might be object but not strings (e.g., mixed types)
            pass

# Save the combined dataframe to Excel
datos_combinados.to_excel(output_path, index=False)

print(f"Proceso completado. DataFrame combinado guardado en: {output_path}")
print(f"Cantidad de filas en el DataFrame combinado: {datos_combinados.shape[0]}")
# Out:
# Proceso completado. DataFrame combinado guardado en: /content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos_2006_2024.xlsx
# Cantidad de filas en el DataFrame combinado: 351920

# %%
import pandas as pd
datos = pd.read_excel("/content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos_2006_2024.xlsx")
print(datos.shape)
datos.head()
# Out:
# (351920, 18)
#    código dane departamento        departamento  código dane municipio  \
# 0                        15              boyaca                  15114
# 1                        25        cundinamarca                  25754
# 2                        25        cundinamarca                  25214
# 3                        54  norte de santander                  54405
# 4                        54  norte de santander                  54518
#
#     municipio grupo cultivo subgrupo cultivo desagregación cultivo   año  \
# 0    busbanza    hortalizas   acelga  acelga                acelga  2006
# 1      soacha    hortalizas   acelga  acelga                acelga  2006
# 2        cota    hortalizas   acelga  acelga                acelga  2006
# 3  los patios    hortalizas   acelga  acelga                acelga  2006
# 4    pamplona    hortalizas   acelga  acelga                acelga  2006
#
#   periodo  área sembrada (ha)  área cosechada (ha)  producción (t)  \
# ...

# %%
import pandas as pd
datos = pd.read_excel("/content/drive/MyDrive/CIENCIA DE DATOS (MICHELL RUIZ)/CORTE2/COLOMBIA/datos_2006_2024.xlsx")
print(datos.shape)
datos.head()

# Cantidad de filas y columnas
print(f"\nCantidad de filas: {datos.shape[0]}")
print(f"Cantidad de columnas: {datos.shape[1]}")

# Cantidad de datos faltantes por columna
print("\nCantidad de datos faltantes por columna:")
print(datos.isnull().sum())

# Cantidad de cultivos únicos
cantidad_cultivos_unicos = datos['cultivo'].nunique()
print(f"\nCantidad de cultivos únicos: {cantidad_cultivos_unicos}")

# Los 10 cultivos con mayor área sembrada
import matplotlib.pyplot as plt
import seaborn as sns

area_sembrada_por_cultivo = datos.groupby('cultivo')['área sembrada (ha)'].sum().sort_values(ascending=False)
top_10_cultivos = area_sembrada_por_cultivo.head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_cultivos.index, y=top_10_cultivos.values, palette='magma') # Changed palette to 'magma'
plt.title('Top 10 Cultivos con Mayor Área Sembrada')
plt.xlabel('Cultivo')
plt.ylabel('Área Sembrada (ha)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# (351920, 18)
#
# Cantidad de filas: 351920
# Cantidad de columnas: 18
#
# Cantidad de datos faltantes por columna:
# código dane departamento              0
# departamento                          0
# código dane municipio                 0
# municipio                             0
# grupo cultivo                         0
# subgrupo                              0
# cultivo                               0
# desagregación cultivo                 0
# año                                   0
# periodo                           97231
# área sembrada (ha)                    0
# área cosechada (ha)                   0
# producción (t)                        0
# rendimiento (t/ha)                 3558
# estado físico del cultivo             0
# nombre científico del cultivo      2983
# ciclo del cultivo                     0
# unnamed: 17                      351827
# dtype: int64
#
# Cantidad de cultivos únicos: 249
# /tmp/ipython-input-2785852631.py:26: FutureWarning:
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate total production by department
produccion_por_departamento = datos['producción (t)'].groupby(datos['departamento']).sum().sort_values(ascending=False)

# Create the bar plot
plt.figure(figsize=(15, 8))
sns.barplot(x=produccion_por_departamento.index, y=produccion_por_departamento.values, palette='plasma') # Changed palette to 'plasma'
plt.title('Producción Total por Departamento')
plt.xlabel('Departamento')
plt.ylabel('Producción (toneladas)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2211980098.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=produccion_por_departamento.index, y=produccion_por_departamento.values, palette='plasma') # Changed palette to 'plasma'
